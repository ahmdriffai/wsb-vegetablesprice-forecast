# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from utils import plot_series, load_data_preprocessing
from sklearn.model_selection import train_test_split

# %%
series = load_data_preprocessing('KTG')
series = series['harga']

# %%
time = np.arange(series.shape[0], dtype="float32")

# Define the split time
split_time = 700

# Get the train set 
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %%
# Plot the train set
plot_series(time_train, x_train)

# %%
# Plot the validation set
plot_series(time_valid, x_valid)

# %%
# Generate the naive forecast
naive_forecast = series[split_time - 1:-1]

# Define time step
time_step = 100

# Print values
print(x_valid.array[100])
print(f'ground truth at time step {time_step}: {x_valid.array[100]}')
print(f'prediction at time step {time_step + 1}: {naive_forecast.array[time_step + 1]}')
# Out:
# 14000.0
# ground truth at time step 100: 14000.0
# prediction at time step 101: 14000.0

# %%
# Plot the results
plot_series(time_valid, (x_valid, naive_forecast))

# %%
# Zooming in
plot_series(time_valid, (x_valid, naive_forecast), start=0, end=150)

# %% [markdown]
# ### Computing Metrics
#
# Now you will compute the [mean squared error](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/mean_squared_error) and the [mean absolute error](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/mean_absolute_error) between the forecasts and the predictions in the validation period. These are available via the [`tf.keras.metrics`](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/) API.

# %%
print(tf.keras.metrics.mean_squared_error(x_valid, naive_forecast).numpy())
print(tf.keras.metrics.mean_absolute_error(x_valid, naive_forecast).numpy())
# Out:
# 36619.718309859156
# 25.35211267605634

# %% [markdown]
# ## Moving Average
#
# One technique you can use is to do a moving average. This sums up a series of time steps and the average will be the prediction for the next time step. For example, the average of the measurements at time steps 1 to 10 will be the forecast for time step 11, then the average for time steps 2 to 11 will be the forecast for time step 12, and so on.
#
# The function below does the moving average for the entire `series`. It takes a `window_size` argument to indicate the number of time steps to consider when computing the mean.

# %%
def moving_average_forecast(series, window_size):
    """Generates a moving average forecast

    Args:
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to compute the average for

    Returns:
      forecast (array of float) - the moving average forecast
    """

    # Initialize a list
    forecast = []
    
    # Compute the moving average based on the window size
    for time in range(len(series) - window_size):
      forecast.append(series[time:time + window_size].mean())
    
    # Convert to a numpy array
    forecast = np.array(forecast)

    return forecast

# %%
# Generate the moving average forecast
moving_avg = moving_average_forecast(series, 30)[split_time - 30:]

# Plot the results
plot_series(time_valid, (x_valid, moving_avg))

# %%
# Compute the metrics
print(tf.keras.metrics.mean_squared_error(x_valid, moving_avg).numpy())
print(tf.keras.metrics.mean_absolute_error(x_valid, moving_avg).numpy())
# Out:
# 540610.3286384977
# 392.9577464788732

# %% [markdown]
# ## Differencing
#
# Since the seasonality period is 365 days, you will subtract the value at time *t* – 365 from the value at time *t*. That is done with the code below.
#
# In addition, you will need to align the result with the `time` array. Since you can only do time differencing for `t >= 365`, you will need to truncate the first 365 time steps of the `time` array.
#
# You can plot the result to visualize the values.

# %%
# Subtract the values at t-365 from original series
diff_series = (series[365:] - series[:-365])

# Truncate the first 365 time steps
diff_time = time[365:]

# Plot the results
plot_series(diff_time, diff_series)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Volumes/DataQ/Tugas Akhir/lstm-predict-potato-price/naive-forecast.ipynb Cell 16 line 8
#       <a href='vscode-notebook-cell:/Volumes/DataQ/Tugas%20Akhir/lstm-predict-potato-price/naive-forecast.ipynb#X33sZmlsZQ%3D%3D?line=4'>5</a> diff_time = time[365:]
#       <a href='vscode-notebook-cell:/Volumes/DataQ/Tugas%20Akhir/lstm-predict-potato-price/naive-forecast.ipynb#X33sZmlsZQ%3D%3D?line=6'>7</a> # Plot the results
# ----> <a href='vscode-notebook-cell:/Volumes/DataQ/Tugas%20Akhir/lstm-predict-potato-price/naive-forecast.ipynb#X33sZmlsZQ%3D%3D?line=7'>8</a> plot_series(diff_time, diff_series)
#
# File /Volumes/DataQ/Tugas Akhir/lstm-predict-potato-price/utils.py:29, in plot_series(time, series, format, start, end)
#      25     plt.plot(time[start:end], series_num[start:end], format)
#      27 else:
#      28   # Plot the time series data
# ---> 29   plt.plot(time[start:end], series[start:end], format)
#      31 # Label the x-axis
#      32 plt.xlabel("Time")
#
# File /Volumes/DataQ/Tugas Akhir/lstm-predict-potato-price/venv/lib/python3.9/site-packages/matplotlib/pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
#    3579         **({"data": data} if data is not None else {}),
#    3580         **kwargs,
#    3581     )
#
# File /Volumes/DataQ/Tugas Akhir/lstm-predict-potato-price/venv/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File /Volumes/DataQ/Tugas Akhir/lstm-predict-potato-price/venv/lib/python3.9/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /Volumes/DataQ/Tugas Akhir/lstm-predict-potato-price/venv/lib/python3.9/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (690,) and (1055,)

# %%
# Generate moving average from the time differenced dataset
diff_moving_avg = moving_average_forecast(diff_series, 30)

# Slice the prediction points that corresponds to the validation set time steps
diff_moving_avg = diff_moving_avg[split_time - 365 - 30:]

# Slice the ground truth points that corresponds to the validation set time steps
diff_series = diff_series[split_time - 365:]

# Plot the results
plot_series(time_valid, (diff_series, diff_moving_avg))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Volumes/DataQ/Tugas Akhir/lstm-predict-potato-price/naive-forecast.ipynb Cell 17 line 1
#       <a href='vscode-notebook-cell:/Volumes/DataQ/Tugas%20Akhir/lstm-predict-potato-price/naive-forecast.ipynb#X34sZmlsZQ%3D%3D?line=7'>8</a> diff_series = diff_series[split_time - 365:]
#      <a href='vscode-notebook-cell:/Volumes/DataQ/Tugas%20Akhir/lstm-predict-potato-price/naive-forecast.ipynb#X34sZmlsZQ%3D%3D?line=9'>10</a> # Plot the results
# ---> <a href='vscode-notebook-cell:/Volumes/DataQ/Tugas%20Akhir/lstm-predict-potato-price/naive-forecast.ipynb#X34sZmlsZQ%3D%3D?line=10'>11</a> plot_series(time_valid, (diff_series, diff_moving_avg))
#
# File /Volumes/DataQ/Tugas Akhir/lstm-predict-potato-price/utils.py:25, in plot_series(time, series, format, start, end)
#      21 if type(series) is tuple:
#      23   for series_num in series:
#      24     # Plot the time series data
# ---> 25     plt.plot(time[start:end], series_num[start:end], format)
#      27 else:
#      28   # Plot the time series data
#      29   plt.plot(time[start:end], series[start:end], format)
#
# File /Volumes/DataQ/Tugas Akhir/lstm-predict-potato-price/venv/lib/python3.9/site-packages/matplotlib/pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
#    3579         **({"data": data} if data is not None else {}),
#    3580         **kwargs,
#    3581     )
#
# File /Volumes/DataQ/Tugas Akhir/lstm-predict-potato-price/venv/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File /Volumes/DataQ/Tugas Akhir/lstm-predict-potato-price/venv/lib/python3.9/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /Volumes/DataQ/Tugas Akhir/lstm-predict-potato-price/venv/lib/python3.9/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (355,) and (720,)
